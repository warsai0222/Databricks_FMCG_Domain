# %%
# %sql
CREATE CATALOG IF NOT EXISTS fmcg;
USE CATALOG fmcg;

# %%
# %sql

--silver and bronze schemas are exclusively for child company, whereas gold will eventually be used for the child company.
--moving under the assumption that the parent company has established gold schema already.
CREATE SCHEMA IF NOT EXISTS fmcg.gold;
CREATE SCHEMA IF NOT EXISTS fmcg.silver;
CREATE SCHEMA IF NOT EXISTS fmcg.bronze;
